# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#    Weather  temp  bool
# 0        0    50     1
# 1        1    35     0
# 2        2    42     1
# 3        0    75     1
# 4        3    20     0
# 5        1    60     1
# 6        4    68     0

# %%
df.head(4)
# Out:
#    Weather  temp  bool
# 0        0    50     1
# 1        1    35     0
# 2        2    42     1
# 3        0    75     1

# %%
df1 = df[df['bool'] == 1]
df2 = df[df['bool'] == 0]
df1
# Out:
#    Weather  temp  bool
# 0        0    50     1
# 2        2    42     1
# 3        0    75     1
# 5        1    60     1

# %%
df2
# Out:
#    Weather  temp  bool
# 1        1    35     0
# 4        3    20     0
# 6        4    68     0

# %%
plt.scatter(df1.Weather, df1.temp, color='green')
plt.scatter(df2.Weather, df2.temp, color='blue')

# %%
x = df[['Weather', 'temp']]
y = df['bool']
y
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# 5    1
# 6    0
# Name: bool, dtype: int64

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
len(xtrain)
# Out:
# 4

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
knn.score(xtest , ytest)
# Out:
# 0.3333333333333333
